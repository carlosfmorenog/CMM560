# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfmorenog/CMM560/blob/main/CMM560_Topic_1/CMM560_T1_2_Lec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Topic 1, Part 2: Introduction to Jupyter Notebook
#
# **NOTE: This is the online version of the one seen during the lecture, therefore some things are different!**

# %% [markdown]
# Remember, Python is the programming language; Jupyter Notebook is the Integrated Development Environment (IDE)!

# %% [markdown]
# ## Types of cells

# %% [markdown]
# #### Code Cells

# %% [markdown]
# In these cells you put your Python Code

# %% [markdown]
# You will recognise them easily, as they have `In []` next to them

# %%
1+1
# Out:
# 2

# %% [markdown]
# #### Markdown Cells

# %% [markdown]
# In these cells you can write comments, section headers, or even import some media!

# %% [markdown]
# Since you will be presenting your coursework as a Jupyter Notebook, I recommend you to have a very good idea of how to use the Markdown cells

# %% [markdown]
# You can check [this post](https://medium.com/analytics-vidhya/the-ultimate-markdown-guide-for-jupyter-notebook-d5e5abf728fd) for the "ultimate" guide on how to use markdown

# %% [markdown]
# ### Keyboard Shortcuts

# %% [markdown]
# Having an idea of the shortcuts will help you produce notebooks faster!

# %% [markdown]
# Check your shortcuts in Tools $\rightarrow$ Keyboard Shortcuts (or press `Ctrl+M H`)

# %% [markdown]
# For instance, you can press `Ctrl+M B` and add a cell below, instead of having to click in the options above or below this cell

# %% [markdown]
# ## Loading images/videos into a Jupyter Notebook

# %% [markdown]
# Images from your local drive (using a Markdown cell):
# 1. When you click on any markdown cell, there will be a menu at the top. The 6th one looks like an "insert image" icon. Use it to import the image you want. Note that this will generate an extremely large code that will slow down your notebook (double click this cell to see it for yourself)! Therefore, I recommend that you insert the images from online sources!
#
# ![Wind_turbines_in_southern_California_2016.png](data:image/png;base64,...)

# %% [markdown]
# Inserting an image online (make sure you have access always)
#
# ![Fig 2.](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cd/Wind_turbines_in_southern_California_2016.jpg/800px-Wind_turbines_in_southern_California_2016.jpg)

# %% [markdown]
# Loading an image AS DATA, you can use packages such as `OpenCV` or `Pillow` (we will use this a lot during the module!)

# %%
## You can clone the repository from GitHub and get the image
# !git clone https://github.com/carlosfmorenog/CMM560
# Out:
# Cloning into 'CMM560'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 173 (delta 3), reused 5 (delta 0), pack-reused 160 (from 2)
# Receiving objects: 100% (173/173), 49.41 MiB | 14.48 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# This cell will work only if the image has been uploaded before
from PIL import Image
im = Image.open("/content/CMM560/CMM560_Topic_1/Wind_turbines_in_southern_California.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=490x367>

# %%
# the variable im contains the pixels of the image
im.size
# Out:
# (490, 367)

# %% [markdown]
# **Inserting a YouTube Video:**
#
# 1. Go to YouTube
# 2. Under "Share" select embed
# 3. You will get an html code, copy it inside the following Python code
#
#         from IPython.display import HTML
#         HTML('embed html code here')

# %%
import warnings;
warnings.simplefilter('ignore')
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/r-uOLxNrNk8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/r-uOLxNrNk8" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Loading data into a Jupyter Notebook

# %% [markdown]
# Just as we loaded the wind farm image as data before, you must know that we can load data from different extensions (.csv, .tsv, .txt, .xlsx) to our notebooks!

# %% [markdown]
# The easiest way to do so is with a Python module called `Pandas`

# %%
import pandas as pd

# %%
# This cell will work only if the file has been uploaded to colab before
data = pd.read_csv('/content/CMM560/CMM560_Topic_1/data.csv')
data
# Out:
#         Name  Age  Height
# 0       Nick   21    1.85
# 1      Chris   29    1.79
# 2        Tim   28    1.75
# 3        Ron   34    1.81
# 4     Monica   35    1.69
# 5  Cassandra   21    1.66

# %% [markdown]
# Commands such as `read_csv` can also take a web address as an input, and load images from online repos!

# %% [markdown]
# For instance, if `data.csv` is in my [Dropbox](https://www.dropbox.com/), I can copy the dropbox link, change `dl=0` for `raw=1` and load the file

# %%
# This command will run anywhere (as long as you have internet connection)
data_dropbox = pd.read_csv('https://www.dropbox.com/s/my97tgyus8s05e1/data.csv?raw=1')
data_dropbox
# Out:
#         Name  Age  Height
# 0       Nick   21    1.85
# 1      Chris   29    1.79
# 2        Tim   28    1.75
# 3        Ron   34    1.81
# 4     Monica   35    1.69
# 5  Cassandra   21    1.66

# %% [markdown]
# # "Lab 1": Installing Python & Jupyter Notebook (or Anaconda) + Signing up for Colab
